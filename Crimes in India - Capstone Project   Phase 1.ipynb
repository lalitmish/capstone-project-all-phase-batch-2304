# %% [markdown]
# #Data Collection/preparation part.

# %% [markdown]
# 1.The population of each state.
#
# 2.Literacy Rate in each state
#
# 3.Area of each state
#
# 4.Collect any other data that helps with your analysis. There is no limitation for anything.
#
# 5.Create a new file and keep the above-collected data.

# %% [markdown]
# #source of data  -https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing dataset

# %% [markdown]
# 1.The population of each state.

# %%
Population=pd.read_csv("List of states and union territories of India by population 2011 census of india.csv")

Population
# Out:
#     sr.no                  State or Union Territory  Population]
# 0       1               Andaman and Nicobar Islands       380581
# 1       2                            Andhra Pradesh     49577103
# 2       3                         Arunachal Pradesh      1383727
# 3       4                                     Assam     31205576
# 4       5                                     Bihar    104099452
# 5       6                                Chandigarh      1055450
# 6       7                              Chhattisgarh     25545198
# 7       8  Dadra and Nagar Haveli and Daman and Diu       585764
# 8       9                                  Delhi UT     16787941
# 9      10                                       Goa      1458545
# 10     11                                   Gujarat     60439692
# 11     12                                   Haryana     25351462
# 12     13                          Himachal Pradesh      6864602
# ...

# %% [markdown]
# We observe that there are total 27 states and 7 union territories in india and highest populated state in india is Uttar Pradesh with population 199812341. as per 2011 census

# %% [markdown]
# 2.Literacy Rate in each state

# %% [markdown]
# #SOURCE - https://www.findeasy.in/indian-states-by-literacy-rate/#State_Wise_Literacy_Rate_in_India

# %%
Literacy_rate=pd.read_csv("Literacy Rate in each state.csv")

Literacy_rate
# Out:
#     sr.no                  State or Union Territory  Population]  Literates  \
# 0       1               Andaman and Nicobar Islands       380581     294281
# 1       2                            Andhra Pradesh     49577103   50556760
# 2       3                         Arunachal Pradesh      1383727     766005
# 3       4                                     Assam     31205576   19177977
# 4       5                                     Bihar    104099452   52504553
# 5       6                                Chandigarh      1055450     805438
# 6       7                              Chhattisgarh     25545198   15379922
# 7       8  Dadra and Nagar Haveli and Daman and Diu       585764     223230
# 8       9                                  Delhi UT     16787941    1342434
# 9      10                                       Goa      1458545     188406
# 10     11                                   Gujarat     60439692   12737767
# ...

# %% [markdown]
# WE observe that out of all states highest literacy rate in Kerala with 94.00%

# %% [markdown]
# 3.Area of each state Area of each state.csv

# %% [markdown]
# #SOURCE -https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area

# %%
Area=pd.read_csv("Area of each state.csv")

Area
# Out:
#     sr.no                  State or Union Territory  Area (km2)  \
# 0       1               Andaman and Nicobar Islands        8249
# 1       2                            Andhra Pradesh      162975
# 2       3                         Arunachal Pradesh       83743
# 3       4                                     Assam       78438
# 4       5                                     Bihar       94163
# 5       6                                Chandigarh         114
# 6       7                              Chhattisgarh      135192
# 7       8  Dadra and Nagar Haveli and Daman and Diu         603
# 8       9                                  Delhi UT       16579
# 9      10                                       Goa        1484
# 10     11                                   Gujarat        3702
# 11     12                                   Haryana      196024
# 12     13                          Himachal Pradesh       44212
# 13     14                         Jammu and Kashmir       55673
# ...

# %%
We observe that rajasthan state is at bigest state in area with 342239 km2

# %% [markdown]
# 4.Collect any other data that helps with your analysis. There is no limitation for anything.
#
# 5.Create a new file and keep the above-collected data.

# %% [markdown]
# Sourse-https://en.wikipedia.org/wiki

# %%
Population_literacy_area=pd.read_csv("List of states and union territories of India by population,literacy and area.csv")

Population_literacy_area
# Out:
#     sr.no                  State or Union Territory  Population]  Literates  \
# 0       1               Andaman and Nicobar Islands       380581     294281
# 1       2                            Andhra Pradesh     49577103   50556760
# 2       3                         Arunachal Pradesh      1383727     766005
# 3       4                                     Assam     31205576   19177977
# 4       5                                     Bihar    104099452   52504553
# 5       6                                Chandigarh      1055450     805438
# 6       7                              Chhattisgarh     25545198   15379922
# 7       8  Dadra and Nagar Haveli and Daman and Diu       585764     223230
# 8       9                                  Delhi UT     16787941    1342434
# 9      10                                       Goa      1458545     188406
# 10     11                                   Gujarat     60439692   12737767
# ...

# %% [markdown]
# #source https://en.wikipedia.org/wiki and India_Crime - Copy.zip
#
# crime type and total crime with population and literacy rate from 2001 to 2012

# %%
Crime_rate=pd.read_csv("different type of crime rate statewise with literacy and population from 2001 to 2011.csv")

Crime_rate
# Out:
#     sr.no                  State or Union Territory  Population]  Population  \
# 0       1               Andaman and Nicobar Islands       380581      380581
# 1       2                            Andhra Pradesh     49577103    84580777
# 2       3                         Arunachal Pradesh      1383727     1383727
# 3       4                                     Assam     31205576    31205576
# 4       5                                     Bihar    104099452   104099452
# 5       6                                Chandigarh      1055450     1055450
# 6       7                              Chhattisgarh     25545198    25545198
# 7       8  Dadra and Nagar Haveli and Daman and Diu       585764      343709
# 8       9                                  Delhi UT     16787941     1978502
# 9      10                                       Goa      1458545      243247
# 10     11                                   Gujarat     60439692    16787941
# ...
