# %% [markdown]
# #Phase 2
#
# State/UT wise analysis.
#
# Note :
#
# 1.	You need to be careful as this phase is whole state/ut wise analysis (not district-wise).
# 2.	It is up to you which columns you want to keep or delete to make proper analysis"
#
#
# 2.1	Analysis of Literacy Rate vs Total Crimes.
#
# 2.2	 Analysis of the type of crime vs each state vs Literacy rate.
#
# 2.3	Analysis of year-on-year total crime rate.
#
# 2.4	 Analysis of area vs overall crime
#
# 2.5	 Analysis of Population vs overall Crime
#
# 2.6	Each state crime report. There is no fixed format to write a report, you can write a report inside the notebook itself based on what you have analyzed in the above points.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %% [markdown]
# # Importing dataset

# %% [markdown]
# 2.1	Analysis of Literacy Rate vs Total Crimes.

# %%
df=pd.read_csv("different type of crime rate statewise with literacy and population from 2001 to 2012.csv")

df
# Out:
#     sr.no                  State or Union Territory  Population  Literates  \
# 0       1               Andaman and Nicobar Islands      380581     294281
# 1       2                            Andhra Pradesh    49577103   50556760
# 2       3                         Arunachal Pradesh     1383727     766005
# 3       4                                     Assam    31205576   19177977
# 4       5                                     Bihar   104099452   52504553
# 5       6                                Chandigarh     1055450     805438
# 6       7                              Chhattisgarh    25545198   15379922
# 7       8  Dadra and Nagar Haveli and Daman and Diu      585764     223230
# 8       9                                  Delhi UT    16787941    1342434
# 9      10                                       Goa     1458545     188406
# 10     11                                   Gujarat    60439692   12737767
# ...

# %%
#checking the null value of  column of dataset
df.isnull().sum()
# Out:
# sr.no                                                        0
# State or Union Territory                                     0
# Population                                                   0
# Literates                                                    0
# Literacy Rate                                                0
# Area (km2)                                                   0
# National share (%)                                           0
# Total MURDER                                                 0
# Total ATTEMPT TO MURDER                                      0
# Total CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# Total RAPE                                                   0
# Total CUSTODIAL RAPE                                         0
# Total OTHER RAPE                                             0
# Total KIDNAPPING & ABDUCTION                                 0
# Total KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# ...

# %% [markdown]
# We observe that there is no null or missing value is present

# %% [markdown]
# 2.1 Analysis of Literacy Rate vs Total Crimes.

# %%
#visualization
plt.bar(df['Literacy Rate'], df['TOTAL CRIMES'])
plt.xlabel('Literacy Rate')
plt.ylabel('TOTAL CRIMES')
plt.show()

# %% [markdown]
# We observe that at literacy rate 82 in that state total crime is highest and at literacy rate 65,70,74,81,86,89,92 total crime
# lowest percentage.  hence we can observe that if literacy rate is high then total crime is low it will not sure for every state
# in some state literacy rate is low but total crime is also low

# %% [markdown]
# 2.2 Analysis of the type of crime vs each state vs Literacy rate.

# %%
# Scatter plot for three columns
plt.scatter(df['sr.no'], df['Literacy Rate'], label='sr.no vs Literacy Rate')
plt.scatter(df['sr.no'], df['Total ATTEMPT TO MURDER'], label='sr.no vs Total ATTEMPT TO MURDER')
plt.scatter(df['Literacy Rate'], df['Total ATTEMPT TO MURDER'], label='Literacy Rate vs Total ATTEMPT TO MURDER')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Comparison of Three Columns')
plt.legend()

# Show the plot
plt.show()

# %%
# Scatter plot for three columns
plt.scatter(df['sr.no'], df['Literacy Rate'], label='sr.no vs Literacy Rate')
plt.scatter(df['sr.no'], df['Total RAPE'], label='sr.no vs Total RAPE')
plt.scatter(df['Literacy Rate'], df['Total RAPE'], label='Literacy Rate vs Total RAPE')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Comparison of Three Columns')
plt.legend()

# Show the plot
plt.show()

# %%
# Line plot for three columns
plt.plot(df['sr.no'], label='sr.no', marker='o')
plt.plot(df['Literacy Rate'], label='Literacy Rate', marker='o')
plt.plot(df['Total CHEATING'], label='Total CHEATING', marker='o')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of state vs literacy vs cheating using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %%
# Line plot for three columns
plt.plot(df['sr.no'], label='sr.no', marker='o')
plt.plot(df['Literacy Rate'], label='Literacy Rate', marker='o')
plt.plot(df['Total KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS'], label='Total KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS', marker='o')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of state vs literacy vs Total KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %%
# Line plot for three columns
plt.plot(df['sr.no'], label='sr.no', marker='o')
plt.plot(df['Literacy Rate'], label='Literacy Rate', marker='o')
plt.plot(df['Total INSULT TO MODESTY OF WOMEN'], label='Total INSULT TO MODESTY OF WOMEN', marker='o')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of state vs literacy vs Total INSULT TO MODESTY OF WOMEN using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# We observe that
# 1. whre literacy rate is high or very low there is approximatly all type of crime percentage is high
# but in states where literacy rate is amedium there were crime rate is moderate
# and between low and average literacy crime is low same as between average and high literacy rate crime is also low

# %% [markdown]
# # 2.3 Analysis of year-on-year total crime rate.

# %%
year_wise_crime=pd.read_csv("year wise crime report.csv")

year_wise_crime
# Out:
#     Year  Sum of CUSTODIAL RAPE  Sum of OTHER RAPE  \
# 0   2001                      0              32150
# 1   2002                      6              32740
# 2   2003                      2              31692
# 3   2004                      4              36462
# 4   2005                     14              36704
# 5   2006                      4              38692
# 6   2007                      2              41472
# 7   2008                      0              42934
# 8   2009                      4              42790
# 9   2010                     12              44332
# 10  2011                      2              48410
# 11  2012                      2              49844
#
#     Sum of KIDNAPPING & ABDUCTION  \
# 0                           44974
# 1                           43700
# 2                           39984
# 3                           46654
# 4                           45664
# 5                           47982
# 6                           55122
# ...

# %%
# Choose two rows to compare
row1 = year_wise_crime.loc[0]
row2 = year_wise_crime.loc[1]

# Line plot for two rows
plt.plot(row1, label='2001', marker='2')
plt.plot(row2, label='2002', marker='2')

# Add labels and title
plt.xlabel('Columns')
plt.ylabel('Values')
plt.title('Comparison of crime 2001 and 2002 using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# we observe that in year 2001 and 2002 crime is approx same

# %%
# Choose two rows to compare
row1 = year_wise_crime.loc[0]
row2 = year_wise_crime.loc[2]

# Line plot for two rows
plt.plot(row1, label='2001', marker='2')
plt.plot(row2, label='2003', marker='2')

# Add labels and title
plt.xlabel('Columns')
plt.ylabel('Values')
plt.title('Comparison of crime 2001 and 2003 using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# we observe that crime in 2003 as compare to 2001 is reduce

# %%
# Choose two rows to compare
row1 = year_wise_crime.loc[0]
row2 = year_wise_crime.loc[3]

# Line plot for two rows
plt.plot(row1, label='2001', marker='2')
plt.plot(row2, label='2004', marker='2')

# Add labels and title
plt.xlabel('Columns')
plt.ylabel('Values')
plt.title('Comparison of crime 2001 and 2004 using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# we observe that crime in 2004 as compare to 2001 is increase

# %%
# Choose two rows to compare
row1 = year_wise_crime.loc[0]
row2 = year_wise_crime.loc[4]

# Line plot for two rows
plt.plot(row1, label='2001', marker='2')
plt.plot(row2, label='2005', marker='2')

# Add labels and title
plt.xlabel('Columns')
plt.ylabel('Values')
plt.title('Comparison of crime 2001 and 2005 using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# we observe that crime in 2005 as compare to 2001 is increase

# %%
# Choose two rows to compare
row1 = year_wise_crime.loc[0]
row2 = year_wise_crime.loc[5]

# Line plot for two rows
plt.plot(row1, label='2001', marker='2')
plt.plot(row2, label='2006', marker='2')

# Add labels and title
plt.xlabel('Index')
plt.ylabel('type of crime')
plt.title('Comparison of crime 2001 and 2006 using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# we observe that crime in 2006 as compare to 2001 is increase

# %%
# Choose two rows to compare
row1 = year_wise_crime.loc[0]
row2 = year_wise_crime.loc[11]

# Line plot for two rows
plt.plot(row1, label='2001', marker='2')
plt.plot(row2, label='2012', marker='2')

# Add labels and title
plt.xlabel('Columns')
plt.ylabel('Values')
plt.title('Comparison of crime 2001 and 2012 using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# we observe that crime is increase year on year from 2001 to 2012

# %% [markdown]
# # 2.4 Analysis of area vs overall crime

# %%
area_vs_overall_crime=pd.read_csv("area_crime.csv")

area_vs_overall_crime
# Out:
#                     State or Union Territory  Area (km2)  \
# 0                Andaman and Nicobar Islands        8249
# 1                             Andhra Pradesh      162975
# 2                          Arunachal Pradesh       83743
# 3                                      Assam       78438
# 4                                      Bihar       94163
# 5                                 Chandigarh         114
# 6                               Chhattisgarh      135192
# 7   Dadra and Nagar Haveli and Daman and Diu         603
# 8                                   Delhi UT       16579
# 9                                        Goa        1484
# 10                                   Gujarat        3702
# 11                                   Haryana      196024
# 12                          Himachal Pradesh       44212
# 13                         Jammu and Kashmir       55673
# 14                                 Jharkhand       42241
# ...

# %%
# Line plot 
plt.plot(area_vs_overall_crime['Area (km2)'], label='Area (km2)', marker='o')
plt.plot(area_vs_overall_crime['Sum of TOTAL IPC CRIMES'], label='Sum of TOTAL IPC CRIMES', marker='o')

# labels and title
plt.xlabel('Area')
plt.ylabel('Crime')
plt.title('Comparison of area and total crime in all states using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# We observe that area of state with 18% there were crime is high  and area with 23% crime is very low

# %% [markdown]
# # 2.5 Analysis of Population vs overall Crime

# %%
# Line plot 
plt.plot(df['Population'], label='Population', marker='o')
plt.plot(df['TOTAL CRIMES'], label='TOTAL CRIMES', marker='o')

# labels and title
plt.xlabel('TOTAL CRIMES')
plt.ylabel('Population')
plt.title('Comparison of Population and total crime in all states using Line Plot')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# We observe that increasing in population crime will also increase but in few states crime will also reduce
# with increase in crime

# %% [markdown]
# # 2.6 Each state crime report. There is no fixed format to write a report, you can write a report inside the notebook itself based on what you have analyzed in the above points.

# %%
df1=pd.read_csv("lowest to highest crime statewise.csv")

df1
# Out:
#                     State or Union Territory  Sum of TOTAL IPC CRIMES
# 0                                Lakshadweep                     1486
# 1                                     Sikkim                    14000
# 2   Dadra and Nagar Haveli and Daman and Diu                    15198
# 3                Andaman and Nicobar Islands                    18204
# 4                                   Nagaland                    26266
# 5                                  Meghalaya                    50498
# 6                                    Mizoram                    52292
# 7                          Arunachal Pradesh                    55304
# 8                                        Goa                    64102
# 9                                 Manipur[c]                    70144
# 10                                Chandigarh                    81614
# 11                                   Tripura                   105468
# ...

# %%
1.we observe that in Lakshadweep there is very low crime as per numbers count and madhyapradesh is at to in 
numbers in alll over tottal crime.
2.We observe that area of state with 18% there were crime is high and area with 23% crime is very low
3.We observe that at literacy rate 82 in that state total crime is highest and at literacy 
rate 65,70,74,81,86,89,92 total crime lowest percentage. hence we can observe that if literacy
rate is high then total crime is low it will not sure for every
state in some state literacy rate is low but total crime is also low
4.we observe that crime is increase year on year from 2001 to 2012

5.highest murder in Uttar Pradesh -130886 lowest in Andaman and Nicobar Islands-320

6.highest rape in Madhya Pradesh-72174 lowest in Lakshadweep -14

7.highest kidnapping in Uttar Pradesh-118532 lowest in Lakshadweep -2

finally we observe that in Lakshadweep there is very low crime as per numbers count and madhyapradesh is at to in 
numbers in alll over tottal crime.
